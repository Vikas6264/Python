# %%
class Demo:
    '''hello world'''
    attr1='vikas'
    att2='hero'

    def method(self):
        print(obj.__dict__)
        self.a=10
        self.b=20
        print(self.a+self.b)
        print(obj.__dict__)


    def method2(self):
        print(obj.__dict__)
        try:
            print(self.a+self.b)
        except Exception as e:
            print(e)

obj=Demo()
obj.method()

print(obj.__dict__)
obj.method2()

print(obj.__dict__)
# Out:
# {}
# 30
# {'a': 10, 'b': 20}
# {'a': 10, 'b': 20}
# {'a': 10, 'b': 20}
# 30
# {'a': 10, 'b': 20}

# %%
class Demo:
  var="vikas"
  var2="Thatiparthi"

  def method():
    print(__init__)
    a=10
    b=2000

# %%
from ast import Add
class Bank:
  Bank_name="SBI"
  ifsc_code="sbio001"

  def __init__(self,account_name,account_number,money):
    self.a=account_name
    self.b=account_number
    self.c=money

  def add_money(self,add_money):
    self.c=self.c+add_money
    return self.c

  def change_name(self):
    self.a="manoj thatiparthi"
    return self.a


vikas=Bank("Thatiparthi Vikas","955023697432",2000)

# venkatesh=Bank("Maliga venkatesh","023984645654",9000)
# print(venkatesh.c)
print(vikas.__dict__)
print(vikas.change_name())
print(vikas.__dict__)

# x=vikas.add_money(3000)
# print(x)
# print(vikas.__dict__)
# Out:
# {'a': 'Thatiparthi Vikas', 'b': '955023697432', 'c': 2000}
# manoj thatiparthi
# {'a': 'manoj thatiparthi', 'b': '955023697432', 'c': 2000}
