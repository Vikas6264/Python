# %%
#capitalization
var="mahitha"
print(var.capitalize())
# Out:
# Mahitha

# %%
#casefold
x="MAHITHA"
print(x.casefold())
# Out:
# mahitha

# %%
#center
var="mahitha"
x=var.center(30)
print(x)
# Out:
#            mahitha

# %%
var="thatiparthi vikas"
k=var.count("t")
print(k)
# Out:
# 3

# %%
var="vikas"
x=var.find("s")
print(x)
# Out:
# 4

# %%
var="iam {pname} and my number is {phone}".format(pname="vikas",phone="7036875251")
print(var)
# Out:
# iam vikas and my number is 7036875251
