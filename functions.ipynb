# %%
def func(lan1):
  print(lan1)

func("python")
# Out:
# python

# %%
def func(**lan1):
  print(lan1)

func(lan="java",lan2="python")
# Out:
# {'lan': 'java', 'lan2': 'python'}

# %%
def func():
    a=10
    b=20
    print(a,b)

func()
# Out:
# 10 20

# %%
n=2
print(n%2)
if n%2==0:
 print("even")
else:
  print("odd")
# Out:
# 0
# even
